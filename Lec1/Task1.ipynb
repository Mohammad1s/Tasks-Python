# %% [markdown]
# Q1

# %%
mylist = [1, 2, 3, 4, 5]
mylist.append(6)
mylist[1] = 10
mylist
# Out:
# [1, 10, 3, 4, 5, 6]

# %% [markdown]
# Q2

# %%
my_list = ['apple', 'banana', 'cherry', 'date']
my_list[0]
# Out:
# 'apple'

# %%
my_list.remove("date")
my_list.insert(2, "grape")
my_list
# Out:
# ['apple', 'banana', 'grape', 'cherry']

# %% [markdown]
# Q3

# %%
my_set1 = {1, 2, 3, 4}
my_set1.add(5) 
my_set1.add(3) #doesn't change as sets don't accept duplicates
my_set1.remove(2)
my_set1
# Out:
# {1, 3, 4, 5}

# %% [markdown]
# Q4

# %%
my_set2 = {'red', 'green', 'blue'}
print("green" in my_set2)
my_set2.add("yellow")
my_set2.remove("red")
my_set2
# Out:
# True
# {'blue', 'green', 'yellow'}

# %% [markdown]
# Q5

# %%
my_tuple = (1, 2, 3, 4, 5)
my_tuple[2]
#my_tuple[1] = 9 #gives an error as tupels are immutable
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# Q6

# %%
my_tuple1 = ('apple', 'banana', 'cherry')
my_tuple1[2]
print("banana" in my_tuple1)
my_tuple1
# Out:
# True
# ('apple', 'banana', 'cherry')

# %% [markdown]
# Q7

# %%
my_dict = {'name': 'John', 'age': 25, 'city': 'New York'}
print(my_dict["name"])
my_dict['age'] = 26
my_dict['job'] = 'Engineer'
my_dict
# Out:
# John
# {'name': 'John', 'age': 26, 'city': 'New York', 'job': 'Engineer'}

# %% [markdown]
# Q8

# %%
my_dict1 = {'brand': 'Toyota', 'model': 'Corolla', 'year': 2019}
print(my_dict1['model'])
my_dict1.pop('year')
my_dict1['color'] = 'blue'
my_dict1
# Out:
# Corolla
# {'brand': 'Toyota', 'model': 'Corolla', 'color': 'blue'}
