# %%
print("Hello DMT5_AIS2_S1")
# Out:
# Hello DMT5_AIS2_S1

# %%
lec1.ipynb # interactive python notebook

# %%
num1= 10 
print(num1)
# Out:
# 10

# %%
print(num1)
# Out:
# 10

# %%
num1= 15

# %%
print("Hello \n Baraa")
# Out:
# Hello
#  Baraa

# %%
print(num1 , "Hello" , "ali" , sep ="*$*" , end = "###")
# Out:
# 10*$*Hello*$*ali###

# %%
num1 = 10
type(num1)
# Out:
# int

# %%
float(num1) # convert int to float
# Out:
# 10.0

# %%
num2 = 20.5
type(num2)
# Out:
# float

# %%
int(num2) # convert float to int
# Out:
# 20

# %%
mystr= "10.1"
type(mystr)
# Out:
# str

# %%
int(mystr) # convert string to float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 int(mystr)
#
# ValueError: invalid literal for int() with base 10: '10.1'

# %%
mybool = True

type(mybool)
mybool * 50
# Out:
# 50

# %%
mybool = False # false is 0 and true is 1
mybool * 50
# Out:
# 0

# %%
PI = 3.14
GRAVITY = 9.8

# %%
# String , list , tuple , set , dictionary

# %%
my_string = "DMT5_AIS2_S1"
           # 0123456789
my_string[4]
# Out:
# '_'

# %%
"AI"  in my_string
# Out:
# True

# %%
path = r"C:\Users\Baraa\Desktop\NEPI 5\lec1.ipynb" 
# r is used to ignore the escape character (raw string)

path
# Out:
# 'C:\\Users\\Baraa\\Desktop\\NEPI 5\\lec1.ipynb'

# %%
my_string[6:10]
# Out:
# 'DMT5'

# %%
num1 = 10

prompt = f""" 

Act As ML engineer 
and write a python code to implement the following:

{num1} is a number and its square is {num1**2} and its cube is {num1**3}
"""
print(prompt)
# Out:
#
#
# Act As ML engineer
# and write a python code to implement the following:
#
# 10 is a number and its square is 100 and its cube is 1000

# %%
num1 = 50

num2 = 8

# %%
num1 + num2
# Out:
# 58

# %%
num1 * num2
# Out:
# 400

# %%
num1 % num2 # 6 * 8 = 48 , 50 - 48 = 2
# Out:
# 2

# %%
num1 ** num2 # 50 ** 8 = 39062500000000 power of 8
# Out:
# 39062500000000

# %%
num1 = 50

num2 = 8
num1 < num2
# Out:
# False

# %%
num1 == num2
# Out:
# False

# %%
num1 != num2
# Out:
# True

# %% [markdown]
# # String  (DONE)
# # , list , tuple , set , dictionary

# %% [markdown]
# # Break 8:10 PM

# %%
# List

# %%
mylist = [  "A" , "B" , "C", ["Baraa", "Ahmed"] ,  1, 2  ]
  #         0      1     2          3              4  5   
mylist

# List is mutable 
# (can be changed) 
# and ordered (indexing is possible)
# Can contain different data types
# Out:
# ['A', 'B', 'C', ['Baraa', 'Ahmed'], 1, 2]

# %%
mylist[2]
# Out:
# 'C'

# %%
mylist[3]
# Out:
# ['Baraa', 'Ahmed']

# %%
mylist[3][0] # indexing inside the list
# Out:
# 'Baraa'

# %%
mylist[3][1] # indexing inside the list
# Out:
# 'Ahmed'

# %%
mylist
# Out:
# ['A', 'B', 'C', ['Baraa', 'Ahmed'], 1, 2]

# %%
mylist.append("D") # add an element to the end of the list

# %%
mylist
# Out:
# ['A', 'B', 'C', ['Baraa', 'Ahmed'], 1, 2, 'D']

# %%
mylist.append("D") 
mylist
# Out:
# ['A', 'B', 'C', ['Baraa', 'Ahmed'], 1, 2, 'D', 'D']

# %%
mylist.insert(2,"D")  # insert an element at a specific index
mylist

# %%
mylist
# Out:
# ['A', 'B', 'D', 'C', ['Baraa', 'Ahmed'], 1, 2, 'D', 'D']

# %%
mylist[5:7]
# Out:
# [1, 2]

# %%
mylist2 = ["ArithmeticError", "AssertionError", "AttributeError" ]

# %%
mylist.append(mylist2)
mylist
# Out:
# ['A',
#  'B',
#  'D',
#  'C',
#  ['Baraa', 'Ahmed'],
#  1,
#  2,
#  'D',
#  'D',
#  ['ArithmeticError', 'AssertionError', 'AttributeError']]

# %%
mylist[9]
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError']

# %%
mylist.extend(mylist2)

# %%
mylist
# Out:
# ['A',
#  'B',
#  'D',
#  'C',
#  ['Baraa', 'Ahmed'],
#  1,
#  2,
#  'D',
#  'D',
#  ['ArithmeticError', 'AssertionError', 'AttributeError'],
#  'ArithmeticError',
#  'AssertionError',
#  'AttributeError']

# %%
mylist[10]
# Out:
# 'ArithmeticError'

# %%
mylist[11]
# Out:
# 'AssertionError'

# %%
len(mylist)
# Out:
# 13

# %%
test_list = ["B","C"]
min(test_list)
# Out:
# 'B'

# %%
test_list[0] = "Ali"
test_list
# Out:
# ['Ali', 'C']

# %%
# Tuple 
# Tuple is immutable (cannot be changed) and ordered (indexing is possible)
# Can do sclicing and indexing like list but cannot change the values

# %%
my_tuple = (  "A" , "B" , "C", ["Baraa", "Ahmed"] ,  1, 2  )

# %%
my_tuple[2]
# Out:
# 'C'

# %%
my_tuple[2] = "Omer"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 my_tuple[2] = "Omer"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Set 
# Set is mutable (can be changed) and unordered (indexing is not possible)
# and cannot contain duplicate values
# and can be used to perform mathematical operations like union, intersection, difference, and symmetric difference.

# %%
myset = set()
type(myset)
# Out:
# set

# %%
myset.add("A")
myset
# Out:
# {'A'}

# %%
myset.add("C")
myset
# Out:
# {'A', 'C'}

# %%
myset.add("A")
myset
# Out:
# {'A', 'C'}

# %%
myset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myset[0]
#
# TypeError: 'set' object is not subscriptable

# %%
myset.discard("A") # remove an element from the set
myset
# Out:
# {'C'}

# %%
A = {1,2,3,4,5}
B = {4,5,6,7,8}

A | B # union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A & B # intersection
# Out:
# {4, 5}

# %%
A - B  # difference
# Out:
# {1, 2, 3}

# %%
B - A  # difference
# Out:
# {6, 7, 8}

# %%
# Dictionary
# Dictionary is mutable (can be changed) and unordered (indexing is not possible)
# Dictionary is a collection of key-value pairs, where each key is unique and maps to a specific value.

# %%
mydict = {"name": "Baraa", "age": 25, "city": "Gaza"}
mydict
# Out:
# {'name': 'Baraa', 'age': 25, 'city': 'Gaza'}

# %%
mydict["name"] # name is the key and Baraa is the value
# Out:
# 'Baraa'

# %%
mydict["age"]

# %%
mydict["name"] = "Ali" # change the value of the key "name"
mydict
# Out:
# {'name': 'Ali', 'age': 25, 'city': 'Gaza'}

# %%
mydict["Name"] = "Omer" 
mydict
# Out:
# {'name': 'Ali', 'age': 25, 'city': 'Gaza', 'Name': 'Omer'}

# %%
mydict.keys() # get all the keys in the dictionary
# Out:
# dict_keys(['name', 'age', 'city', 'Name'])

# %%
mydict.values() # get all the values in the dictionary
# Out:
# dict_values(['Ali', 25, 'Gaza', 'Omer'])

# %%
dict_items = mydict.items()

# %%
        # accuracy, recall, precision, f1_score
mytuple = (90, 80, 70, 60)
 
accuracy , recall, precision, f1_score = mytuple  # unpacking the tuple into separate variables

# %%
accuracy
# Out:
# 90

# %%
precision
# Out:
# 70

# %%
for key, value in mydict.items():
    print("key is:", key, "and value is:", value)
# Out:
# key is: name and value is: Ali
# key is: age and value is: 25
# key is: city and value is: Gaza
# key is: Name and value is: Omer

# %% [markdown]
# # If Else , For loops , Next time
